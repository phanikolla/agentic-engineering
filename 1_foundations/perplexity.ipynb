# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv(override=True)

from perplexity import Perplexity

client = Perplexity() # Automatically

# %%
# chat with grounded serach

completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "What are the major AI developments and announcements from today across the tech industry?"
        }
    ],
    model="sonar-pro"
)

print(completion.choices[0].message.content)
# Out:
# Today has seen a significant wave of AI announcements and developments across the technology industry. Here's what's happening:
#
# ## Shopping and E-Commerce
#
# Major tech companies are making aggressive pushes into AI-assisted holiday shopping. OpenAI unveiled **Shopping Research**, a new feature powered by ChatGPT-5 mini that conducts deep product reconnaissance across the web, though it cannot yet handle direct purchases[2]. Perplexity launched its own AI personal shopper with an Instant Buy feature integrated with PayPal[2]. Google is expanding its AI Mode in the Gemini app and Search, allowing users to track price changes and visit retailer sites, though currently only with a limited set of merchants including Wayfair, Chewy, and Quince[2].
#
# Retail giants are also rolling out their own solutions. **Amazon upgraded Rufus**, its AI assistant, with expanded capabilities including automatic cart additions, price comparison, and the ability to process handwritten shopping lists[2]. **Walmart launched Sparky**, a conversational AI shopping assistant that can suggest items for events like parties or holiday dinners[2]. **Target** improved its AI-powered gift finder with integrations allowing direct purchases through ChatGPT[2]. Between 15% and 30% of online shoppers are expected to use generative AI for holiday gift shopping this year[2].
#
# ## Enterprise and Cloud Infrastructure
#
# **SAP and Cohere** announced a partnership to deliver frontier agentic AI capabilities, with Cohere North being integrated into SAP's Business Technology Platform to help enterprises build AI into their core business processes while maintaining data sovereignty and compliance[3].
#
# **NTT DATA** has been recognized as a Leader in Everest Group's Microsoft AI Services PEAK Matrix Assessment[6].
#
# **IBM** is prioritizing business-to-business startups in AI and quantum computing that can integrate into its enterprise ecosystem[5].
#
# ## Weather and Research
#
# **Google DeepMind and Google Research** released WeatherNext 2, an advanced forecasting model capable of predicting hundreds of weather scenarios in under a minute—eight times faster than previous models[1]. The technology has been integrated across Google's apps including Gemini, Search, Pixel Weather, and Google Maps[1].
#
# ## Healthcare and Academic Initiatives
#
# The **University of Westminster** launched its AI Network to expand AI research collaboration, bringing together 81 participants at its launch event and establishing partnerships that are already pursuing external funding[4].
#
# ## Government and Veteran Support
#
# **OpenAI** announced free access to ChatGPT Plus for U.S. servicemembers and veterans within 12 months of retirement or separation, including access to the latest models and specialized resources[1].

# %% [markdown]
# Tier 0:
#
# Model	Requests per minute (RPM)
# sonar-deep-research	5
# sonar-reasoning-pro	50
# sonar-reasoning	50
# sonar-pro	50
# sonar	50
# POST /async/chat/completions	5
# GET /async/chat/completions	3000
# GET /async/chat/completions/{request_id}	6000
