# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv(override=True)
# Out:
# True

# %%
# import xai_sdk
from xai_sdk import Client
from xai_sdk.chat import user, system

# %%
client = Client(
    api_key=os.getenv("XAI_API_KEY"),
    timeout=3600, # Override default timeout with longer timeout for reasoning models
)
chat = client.chat.create(model="grok-4-1-fast-reasoning")
chat.append(system("You are a PhD-level mathematician."))
chat.append(user("What is 2 + 2?"))
response = chat.sample()
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# Cell In[6], line 8
#       6 chat.append(system("You are a PhD-level mathematician."))
#       7 chat.append(user("What is 2 + 2?"))
# ----> 8 response = chat.sample()
#       9 print(response.content)
#
# File c:\Users\phani\AppData\Local\Programs\Python\Python313\Lib\site-packages\xai_sdk\sync\chat.py:108, in Chat.sample(self)
#     102 with tracer.start_as_current_span(
#     103     name=f"chat.sample {self._proto.model}",
#     104     kind=SpanKind.CLIENT,
#     105     attributes=self._make_span_request_attributes(),
#     106 ) as span:
#     107     index = None if self._uses_server_side_tools() else 0
# --> 108     response_pb = self._stub.GetCompletion(self._make_request(1))
#     109     index = self._auto_detect_multi_output_mode(index, response_pb.outputs)
#     110     response = Response(response_pb, index)
#
# File c:\Users\phani\AppData\Local\Programs\Python\Python313\Lib\site-packages\grpc\_interceptor.py:276, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     267 def __call__(
#     268     self,
#     269     request: Any,
#    (...)    274     compression: Optional[grpc.Compression] = None,
#     275 ) -> Any:
# --> 276     response, ignored_call = self._with_call(
#     277         request,
#     278         timeout=timeout,
#     279         metadata=metadata,
#     280         credentials=credentials,
#     281         wait_for_ready=wait_for_ready,
#     282         compression=compression,
#     283     )
#     284     return response
#
# File c:\Users\phani\AppData\Local\Programs\Python\Python313\Lib\site-packages\grpc\_interceptor.py:331, in _UnaryUnaryMultiCallable._with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     326         return _FailureOutcome(exception, sys.exc_info()[2])
#     328 call = self._interceptor.intercept_unary_unary(
#     329     continuation, client_call_details, request
#     330 )
# --> 331 return call.result(), call
#
# File c:\Users\phani\AppData\Local\Programs\Python\Python313\Lib\site-packages\grpc\_channel.py:438, in _InactiveRpcError.result(self, timeout)
#     434 def result(
#     435     self, timeout: Optional[float] = None
#     436 ) -> Any:  # pylint: disable=unused-argument
#     437     """See grpc.Future.result."""
# --> 438     raise self
#
# File c:\Users\phani\AppData\Local\Programs\Python\Python313\Lib\site-packages\grpc\_interceptor.py:314, in _UnaryUnaryMultiCallable._with_call.<locals>.continuation(new_details, request)
#     305 (
#     306     new_method,
#     307     new_timeout,
#    (...)    311     new_compression,
#     312 ) = _unwrap_client_call_details(new_details, client_call_details)
#     313 try:
# --> 314     response, call = self._thunk(new_method).with_call(
#     315         request,
#     316         timeout=new_timeout,
#     317         metadata=new_metadata,
#     318         credentials=new_credentials,
#     319         wait_for_ready=new_wait_for_ready,
#     320         compression=new_compression,
#     321     )
#     322     return _UnaryOutcome(response, call)
#     323 except grpc.RpcError as rpc_error:
#
# File c:\Users\phani\AppData\Local\Programs\Python\Python313\Lib\site-packages\grpc\_channel.py:1180, in _UnaryUnaryMultiCallable.with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1168 def with_call(
#    1169     self,
#    1170     request: Any,
#    (...)   1175     compression: Optional[grpc.Compression] = None,
#    1176 ) -> Tuple[Any, grpc.Call]:
#    1177     state, call = self._blocking(
#    1178         request, timeout, metadata, credentials, wait_for_ready, compression
#    1179     )
# -> 1180     return _end_unary_response_blocking(state, call, True, None)
#
# File c:\Users\phani\AppData\Local\Programs\Python\Python313\Lib\site-packages\grpc\_channel.py:996, in _end_unary_response_blocking(state, call, with_call, deadline)
#     994         return state.response, rendezvous
#     995     return state.response
# --> 996 raise _InactiveRpcError(state)
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.PERMISSION_DENIED
# 	details = "Your newly created teams doesn't have any credits yet. You can purchase credits on https://console.x.ai/team/b4371f75-a68f-486a-9894-2061bac6657d."
# 	debug_error_string = "UNKNOWN:Error received from peer  {grpc_status:7, grpc_message:"Your newly created teams doesn\'t have any credits yet. You can purchase credits on https://console.x.ai/team/b4371f75-a68f-486a-9894-2061bac6657d."}"
# >

# %% [markdown]
# Tier 0:
#
# Model	Requests per minute (RPM)
# sonar-deep-research	5
# sonar-reasoning-pro	50
# sonar-reasoning	50
# sonar-pro	50
# sonar	50
# POST /async/chat/completions	5
# GET /async/chat/completions	3000
# GET /async/chat/completions/{request_id}	6000
